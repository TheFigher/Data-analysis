# %% [markdown]
# # 1.明确需求和目的

# %% [markdown]
# 对一家全球超市四年（2011-2014）的销售数据进行 人、货、场分析，并给出提升销量的针对性建议。
#
# 场：整体运营情况分析，包括销售额、销量、利润、客单价、市场布局等具体情况分析。
#
# 货：商品结构、优势/爆款商品、劣势/待优化商品等情况分析。
#
# 人：客户数量、新老客户、RFM模型、复购率、回购率等用户行为分析。

# %% [markdown]
# # 2.数据来源

# %% [markdown]
# 数据来源为kaggle平台，这是一份全球大型超市四年的零售数据集，数据详尽。
#
# 数据集为superstore_dataset2011-2015.csv，共有51290条数据，共24个特征。

# %% [markdown]
# # 3.数据预处理

# %% [markdown]
# ### 3.1数据整合

# %% [markdown]
# #### 3.1.1加载相关库和数据集

# %%
# 加载库
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
warnings.filterwarnings('ignore')

# %%
# 加载数据
df = pd.read_csv(r'E:\数据分析项目\三、超市零售分析\data\superstore_dataset2011-2015.csv', encoding='ISO-8859-1')
df.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# 1   OFF-SU-10000618  Office Supplies     Supplies
# 2  OFF-TEN-10001585  Office Supplies      Storage
# 3   OFF-PA-10001492  Office Supplies        Paper
# 4   FUR-FU-10003447        Furniture  Furnishings
#
#                   Product Name    Sales Quantity Discount   Profit  \
# 0          Tenex Lockers, Blue  408.300        2      0.0  106.140
# 1     Acme Trimmer, High Speed  120.366        3      0.1   36.036
# 2      Tenex Box, Single Width   66.120        4      0.0   29.640
# 3  Enermax Note Cards, Premium   44.865        3      0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack  113.670        5      0.1   37.770
#
#    Shipping Cost  Order Priority
# 0          35.46          Medium
# 1           9.72          Medium
# 2           8.17            High
# 3           4.82            High
# 4           4.70          Medium
#
# [5 rows x 24 columns]

# %% [markdown]
# #### 3.1.2 数据概览

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375915
# std      174.340972      57.296804
# min    -6599.978000       0.000000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# max     8399.976000     933.570000

# %% [markdown]
# ### 3.2数据清洗

# %% [markdown]
# #### 3.2.1列名重命名

# %%
# 观察数据发现  列名存在不符合python标准的命名规范  对列名进行重命名  使用下划线命名法
df.rename(columns=lambda x: x.replace(' ','_').replace('-','_'), inplace=True)
df.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'City', 'State', 'Country',
#        'Postal_Code', 'Market', 'Region', 'Product_ID', 'Category',
#        'Sub_Category', 'Product_Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping_Cost', 'Order_Priority'],
#       dtype='object')

# %% [markdown]
# #### 3.2.2数据类型处理

# %%
df.dtypes
# Out:
# Row_ID              int64
# Order_ID           object
# Order_Date         object
# Ship_Date          object
# Ship_Mode          object
# Customer_ID        object
# Customer_Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal_Code       float64
# Market             object
# Region             object
# Product_ID         object
# Category           object
# Sub_Category       object
# Product_Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping_Cost     float64
# Order_Priority     object
# dtype: object

# %% [markdown]
# 大部分数据类型是object，销量、销售额、利润等数据类型是数值型，不需要处理。下单日期应该是datatime类型，更改一下

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df["Order_Date"].sample(5)
# Out:
# 24607   2011-10-15
# 28112   2014-11-17
# 4742    2012-04-07
# 32652   2013-07-20
# 4051    2012-02-08
# Name: Order_Date, dtype: datetime64[ns]

# %%
# 便于分析每年每月销售情况 添加两个字段  年   月
df['year'] = df['Order_Date'].dt.year
df['month'] = df['Order_Date'].values.astype('datetime64[M]')

# %% [markdown]
# #### 3.2.3缺失值处理

# %%
# 缺失值处理
df.isnull().sum(axis=0)
# Out:
# Row_ID                0
# Order_ID              0
# Order_Date            0
# Ship_Date             0
# Ship_Mode             0
# Customer_ID           0
# Customer_Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal_Code       41296
# Market                0
# Region                0
# Product_ID            0
# Category              0
# Sub_Category          0
# Product_Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping_Cost         0
# Order_Priority        0
# year                  0
# month                 0
# dtype: int64

# %%
# Postal_Code 邮编缺失很多数据  对分析无用直接删除
df.drop(['Postal_Code'], axis=1, inplace=True)

# %% [markdown]
# #### 3.2.4异常值处理

# %%
# 异常值处理(未发现明显异常值)
df.describe()
# Out:
#             Row_ID         Sales      Quantity      Discount        Profit  \
# count  51290.00000  51290.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000    246.490581      3.476545      0.142908     28.610982
# std    14806.29199    487.565361      2.278766      0.212280    174.340972
# min        1.00000      0.444000      1.000000      0.000000  -6599.978000
# 25%    12823.25000     30.758625      2.000000      0.000000      0.000000
# 50%    25645.50000     85.053000      3.000000      0.000000      9.240000
# 75%    38467.75000    251.053200      5.000000      0.200000     36.810000
# max    51290.00000  22638.480000     14.000000      0.850000   8399.976000
#
#        Shipping_Cost          year
# count   51290.000000  51290.000000
# mean       26.375915   2012.777208
# std        57.296804      1.098931
# min         0.000000   2011.000000
# 25%         2.610000   2012.000000
# 50%         7.790000   2013.000000
# 75%        24.450000   2014.000000
# max       933.570000   2014.000000

# %% [markdown]
# #### 3.2.5重复值处理

# %%
# 重复值处理(无重复值  不需要处理)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 4.数据分析

# %% [markdown]
# ### 4.1整体销售情况分析

# %%
# 整体销售情况包含的字段（下单日期、销售额、销量、利润、年份、月份）
sales_data = df[['Order_Date', 'Sales', 'Quantity', 'Profit', 'year', 'month']]
sales_data.sample(5)
# Out:
#       Order_Date    Sales  Quantity  Profit  year      month
# 17348 2014-08-08  287.940         2   0.000  2014 2014-08-01
# 45791 2011-02-28  401.280        10  -5.220  2011 2011-02-01
# 17678 2014-09-01  336.528         8  74.688  2014 2014-09-01
# 22658 2014-07-14   25.920         3   3.060  2014 2014-07-01
# 10922 2013-08-01  657.765         3 -65.835  2013 2013-08-01

# %%
# 按照年份 月份对其分组求和
sales_year = sales_data.groupby(['year', 'month']).sum()
sales_year
# Out:
#                         Sales  Quantity       Profit
# year month
# 2011 2011-01-01  138241.30042      2178  13457.23302
#      2011-02-01  134969.94086      1794  17588.83726
#      2011-03-01  171455.59372      2183  16169.36062
#      2011-04-01  128833.47034      2181  13405.46924
#      2011-05-01  148146.72092      2057  14777.45792
#      2011-06-01  189338.43966      2715  25932.87796
#      2011-07-01  162034.69756      2266  10631.84406
#      2011-08-01  219223.49524      2909  19650.67124
#      2011-09-01  255237.89698      3357  32313.25458
#      2011-10-01  204675.07846      2615  30745.54166
#      2011-11-01  214934.29386      3165  21261.40536
#      2011-12-01  292359.96752      4023  33006.85862
# 2012 2012-01-01  162800.89338      2150  19627.42058
#      2012-02-01  152661.15144      2156  17828.18244
#      2012-03-01  201608.72784      2880  22752.87684
#      2012-04-01  187469.96192      2506  20804.00532
#      2012-05-01  218960.16042      3239  22865.39572
#      2012-06-01  249289.77172      3508  34358.03962
#      2012-07-01  174394.02808      2551  21725.18808
#      2012-08-01  271669.66086      3451  36511.44996
#      2012-09-01  256567.85308      3752  25039.93498
#      2012-10-01  239321.09904      3399  27773.87454
#      2012-11-01  270723.05356      4497  26160.60686
#      2012-12-01  291972.33306      4022  31968.30416
# 2013 2013-01-01  206459.19582      2766  26052.40252
#      2013-02-01  191062.77216      2535  31553.99756
#      2013-03-01  230547.79468      3130  34873.71938
#      2013-04-01  233181.34844      3161  26008.05144
#      2013-05-01  304509.96336      4115  39053.30946
#      2013-06-01  341162.34370      4948  43298.85000
#      2013-07-01  223642.65664      3594  27019.91294
#      2013-08-01  323876.60716      4564  32977.75576
#      2013-09-01  326897.27044      5067  18850.09084
#      2013-10-01  270121.87570      3977  27871.97470
#      2013-11-01  383039.21248      5274  51720.88568
#      2013-12-01  371245.40880      5005  47654.27990
# 2014 2014-01-01  268265.52240      3656  31447.74660
#      2014-02-01  244159.30486      3450  29454.01876
#      2014-03-01  347720.96868      4820  50097.04458
#      2014-04-01  302132.54000      4397  35709.53320
#      2014-05-01  304798.83604      4415  34335.60404
#      2014-06-01  372577.23298      5528  40869.02108
#      2014-07-01  278672.17326      3867  26450.70856
#      2014-08-01  432731.04194      5506  46443.47934
#      2014-09-01  405436.70584      5741  52533.83284
#      2014-10-01  406659.41500      5915  52342.49740
#      2014-11-01  508954.73156      7020  55561.72406
#      2014-12-01  427757.39800      6307  48920.76000

# %%
#  slice(None), 是Python中的切片操作
year_2011 = sales_year.loc[(2011,slice(None)),:].reset_index()
year_2012 = sales_year.loc[(2012,slice(None)),:].reset_index()
year_2013 = sales_year.loc[(2013,slice(None)),:].reset_index()
year_2014 = sales_year.loc[(2014,slice(None)),:].reset_index()
year_2014
# Out:
#     year      month         Sales  Quantity       Profit
# 0   2014 2014-01-01  268265.52240      3656  31447.74660
# 1   2014 2014-02-01  244159.30486      3450  29454.01876
# 2   2014 2014-03-01  347720.96868      4820  50097.04458
# 3   2014 2014-04-01  302132.54000      4397  35709.53320
# 4   2014 2014-05-01  304798.83604      4415  34335.60404
# 5   2014 2014-06-01  372577.23298      5528  40869.02108
# 6   2014 2014-07-01  278672.17326      3867  26450.70856
# 7   2014 2014-08-01  432731.04194      5506  46443.47934
# 8   2014 2014-09-01  405436.70584      5741  52533.83284
# 9   2014 2014-10-01  406659.41500      5915  52342.49740
# 10  2014 2014-11-01  508954.73156      7020  55561.72406
# 11  2014 2014-12-01  427757.39800      6307  48920.76000

# %% [markdown]
# #### 4.1.1销售额分析

# %%
# 销售额分析
# 1、构建销售表
sales = pd.concat([year_2011['Sales'],year_2012['Sales'],year_2013['Sales'],
                   year_2014['Sales']], axis=1)
# 2、对各行各列重命名
sales.columns = ['Sales-2011', 'Sales-2012', 'Sales-2013', 'Sales-2014']
sales.index = ['Jau','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# 3、颜色越深  销售额越高
sales.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_09598302_ae19_11ea_8ec0_b42e998e8a14row0_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row0_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row0_col2 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row0_col3 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row1_col0 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row2_col0 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row2_col1 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row2_col2 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row2_col3 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row3_col1 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row3_col2 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row3_col3 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row4_col0 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row4_col1 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row4_col2 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row4_col3 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row5_col0 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row5_col1 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row5_col2 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row5_col3 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row6_col0 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row6_col1 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row6_col2 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row6_col3 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row7_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row7_col1 {
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row7_col2 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row7_col3 {
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row8_col0 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row8_col1 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row8_col2 {
#             background-color:  #157ab5;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row8_col3 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row9_col0 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row9_col1 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row9_col2 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row9_col3 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row10_col0 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row10_col1 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row10_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row11_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row11_col2 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_09598302_ae19_11ea_8ec0_b42e998e8a14row11_col3 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }</style><table id="T_09598302_ae19_11ea_8ec0_b42e998e8a14" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sales-2011</th>        <th class="col_heading level0 col1" >Sales-2012</th>        <th class="col_heading level0 col2" >Sales-2013</th>        <th class="col_heading level0 col3" >Sales-2014</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09598302_ae19_11ea_8ec0_b42e998e8a14level0_row0" class="row_heading level0 row0" >Jau</th>
#                         <td id="T_09598302_ae19_11ea_8ec0_b42e998e8a14row0_col0" class="data row0 col0" >138241</td>
#                         <td id="T_09598302_ae19_11ea_8ec0_b42e998e8a14row0_col1" class="data row0 col1" >162801</td>
#                         <td id="T_09598302_ae19_11ea_8ec0_b42e998e8a14row0_col2" class="data row0 col2" >206459</td>
#                         <td id="T_09598302_ae19_11ea_8ec0_b42e998e8a14row0_col3" class="data row0 col3" >268266</td>
#             </tr>
#             <tr>
#                         <th id="T_09598302_ae19_11ea_8ec0_b42e998e8a14level0_row1" class="row_heading level0 row1" >Feb</th>
#                         <td id="T_09598302_ae19_11ea_8ec0_b42e998e8a14row1_col0" class="data row1 col0" >134970</td>
#                         <td id="T_09598302_ae19_11ea_8ec0_b42e998e8a14row1_col1" class="data row1 col1" >152661</td>
#                         <td id="T_09598302_ae19_11ea_8ec0_b42e998e8a14row1_col2" class="data row1 col2" >191063</td>
#                         <td id="T_09598302_ae19_11ea_8ec0_b42e998e8a14row1_col

# %% [markdown]
# 从上图可以看出，基本上每一年都是下半年销售额比上半年要高，而且随着年份的增大，销售额也有明显的增加，说明销售业绩增长较快，发展还是比较好的。

# %%
# 增长率   每年销售总额
# 1、计算年度销售额
sales_sum = sales.sum()
sales_sum.plot(kind='bar', alpha=0.5)
plt.grid()

#2、计算每年增长率
rise_12=sales_sum[1]/sales_sum[0]-1
rise_13=sales_sum[2]/sales_sum[1]-1
rise_14=sales_sum[3]/sales_sum[2]-1
rise_rate=[0,rise_12,rise_13,rise_14]


sales_sum = pd.DataFrame({'Sales_sum':sales_sum})
sales_sum['rise_rate'] = rise_rate
sales_sum
# Out:
#                Sales_sum  rise_rate
# Sales-2011  2.259451e+06   0.000000
# Sales-2012  2.677439e+06   0.184995
# Sales-2013  3.405746e+06   0.272017
# Sales-2014  4.299866e+06   0.262533

# %% [markdown]
# 从上面可以看出，后两年的销售额增长率达到26%，2014年销售额将近是2011的两倍，发展势头良好，经营在逐步稳定。结合年度销售额及增长率，再结合公司整体战略规划，可以预测或制定下一年度总销售额业绩指标。
#
#
# 了解了超市整体销售额后，再对每年每月的销售额进行分析，了解不同月份的销售情况，找出是否有淡旺季之分，找出重点销售月份，以便制定经营策略与业绩月度及季度指标拆分。

# %%
sales.plot.area(stacked=False)

# %% [markdown]
# 从上图可以大致看出，该超市的销售季节性明显，总体上半年是淡季，下半年是旺季。上半年中6月份销售额比较高，下半年中7月份的销售额偏低。

# %% [markdown]
# 对于旺季的月份，运营推广等策略要继续维持，还可以加大投入，提高整体销售额。
#
# 对于旺季的月份，运营推广等策略要继续维持，还可以加大投入，提高整体销售额。

# %% [markdown]
# #### 4.1.2销量分析

# %%
#  销量分析
quantity = pd.concat([year_2011['Quantity'],year_2012['Quantity'],
                 year_2013['Quantity'],year_2014['Quantity']],axis=1)

# 对行名和列名进行重命名
quantity.columns=['Quantity-2011','Quantity-2012','Quantity-2013','Quantity-2014']
quantity.index=['Jau','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# 颜色越深，销量越高
quantity.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row0_col0 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row0_col2 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row0_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row2_col0 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row2_col1 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row2_col2 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row2_col3 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row3_col0 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row3_col1 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row3_col2 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row3_col3 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row4_col0 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row4_col1 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row4_col2 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row4_col3 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row5_col0 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row5_col1 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row5_col2 {
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row5_col3 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row6_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row6_col1 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row6_col2 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row6_col3 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row7_col0 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row7_col1 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row7_col2 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row7_col3 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row8_col0 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row8_col1 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row8_col2 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row8_col3 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row9_col0 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row9_col1 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row9_col2 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row9_col3 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row10_col0 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row10_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row10_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row11_col1 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row11_col2 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_09bd452e_ae19_11ea_aed9_b42e998e8a14row11_col3 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }</style><table id="T_09bd452e_ae19_11ea_aed9_b42e998e8a14" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Quantity-2011</th>        <th class="col_heading level0 col1" >Quantity-2012</th>        <th class="col_heading level0 col2" >Quantity-2013</th>        <th class="col_heading level0 col3" >Quantity-2014</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09bd452e_ae19_11ea_aed9_b42e998e8a14level0_row0" class="row_heading level0 row0" >Jau</th>
#                         <td id="T_09bd452e_ae19_11ea_aed9_b42e998e8a14row0_col0" class="data row0 col0" >2178</td>
#                         <td id="T_09bd452e_ae19_11ea_aed9_b42e998e8a14row0_col1" class="data row0 col1" >2150</td>
#                         <td id="T_09bd452e_ae19_11ea_aed9_b42e998e8a14row0_col2" class="data row0 col2" >2766</td>
#                         <td id="T_09bd452e_ae19_11ea_aed9_b42e998e8a14row0_col3" class="data row0 col3" >3656</td>
#             </tr>
#             <tr>
#                         <th id="T_09bd452e_ae19_11ea_aed9_b42e998e8a14level0_row1" class="row_heading level0 row1" >Feb</th>
#                         <td id="T_09bd452e_ae19_11ea_aed9_b42e998e8a14row1_col0" class="data row1 col0" >1794</td>
#                         <td id="T_09bd452e_ae19_11ea_aed9_b42e998e8a14row1_col1" class="data row1 col1" >2156</td>
#                         <td id="T_09bd452e_ae19_11ea_aed9_b42e998e8a14row1_col2" class="data row1 col2" >2535</td>
#                         <td id="T_09bd452e_ae19_11ea_aed9_b42e998e8a14row1_col3"

# %%
# 看一下销量增长率和每年的销量总和。
# 计算年度销量并图表展示
quantity_sum=quantity.sum()
quantity_sum.plot(kind='bar',alpha=0.5)
plt.grid()

# 计算每年增长率
rise_12=quantity_sum[1]/quantity_sum[0]-1
rise_13=quantity_sum[2]/quantity_sum[1]-1
rise_14=quantity_sum[3]/quantity_sum[2]-1
rise_rate=[0,rise_12,rise_13,rise_14]

# 显示增长率
quantity_sum=pd.DataFrame({'quantity_sum':quantity_sum})
quantity_sum['rise_rate']=rise_rate
quantity_sum
# Out:
#                quantity_sum  rise_rate
# Quantity-2011         31443   0.000000
# Quantity-2012         38111   0.212066
# Quantity-2013         48136   0.263047
# Quantity-2014         60622   0.259390

# %% [markdown]
# 从上面可以看出，2011-2014年销量变化趋势与销售额是一样的，下半年销量整体高于上半年，同时销量同比上一年均在提高。

# %% [markdown]
# #### 4.1.3利润分析

# %%
# 利润分析
profit=pd.concat([year_2011['Profit'],year_2012['Profit'],
                 year_2013['Profit'],year_2014['Profit']],axis=1)
profit.columns=['Profit-2011','Profit-2012','Profit-2013','Profit-2014']
profit.index=['Jau','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

profit.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row0_col0 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row0_col1 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row0_col2 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row0_col3 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row1_col0 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row1_col2 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row1_col3 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row2_col0 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row2_col1 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row2_col2 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row2_col3 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row3_col0 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row3_col1 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row3_col2 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row3_col3 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row4_col0 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row4_col1 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row4_col2 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row4_col3 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row5_col0 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row5_col1 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row5_col2 {
#             background-color:  #0771b1;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row5_col3 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row6_col1 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row6_col2 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row7_col0 {
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row7_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row7_col2 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row7_col3 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row8_col0 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row8_col1 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row8_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row8_col3 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row9_col0 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row9_col1 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row9_col2 {
#             background-color:  #c8cde4;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row9_col3 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row10_col0 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row10_col1 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row10_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row11_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row11_col1 {
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row11_col2 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row11_col3 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }</style><table id="T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Profit-2011</th>        <th class="col_heading level0 col1" >Profit-2012</th>        <th class="col_heading level0 col2" >Profit-2013</th>        <th class="col_heading level0 col3" >Profit-2014</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14level0_row0" class="row_heading level0 row0" >Jau</th>
#                         <td id="T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row0_col0" class="data row0 col0" >13457.2</td>
#                         <td id="T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row0_col1" class="data row0 col1" >19627.4</td>
#                         <td id="T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row0_col2" class="data row0 col2" >26052.4</td>
#                         <td id="T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row0_col3" class="data row0 col3" >31447.7</td>
#             </tr>
#             <tr>
#                         <th id="T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14level0_row1" class="row_heading level0 row1" >Feb</th>
#                         <td id="T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row1_col0" class="data row1 col0" >17588.8</td>
#                         <td id="T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row1_col1" class="data row1 col1" >17828.2</td>
#                         <td id="T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a14row1_col2" class="data row1 col2" >31554</td>
#                         <td id="T_09cf5a1c_ae19_11ea_9d5f_b42e998e8a1

# %%
# 计算每年总利润和利润率
# 计算年度总利润并图表展示
profit_sum=profit.sum()
profit_sum.plot(kind='bar',alpha=0.5)
plt.grid()

profit_sum=pd.DataFrame({'profit_sum':profit_sum})
profit_sum["year"] =  [2011, 2012, 2013, 2014]

sales_sum=pd.DataFrame({'sales_sum':sales.sum()})
sales_sum["year"] =  [2011, 2012, 2013, 2014]

profit_sum = pd.merge(profit_sum, sales_sum)
profit_sum["profit_rate"] = profit_sum["profit_sum"] / profit_sum["sales_sum"]
profit_sum
# Out:
#      profit_sum  year     sales_sum  profit_rate
# 0  248940.81154  2011  2.259451e+06     0.110178
# 1  307415.27910  2012  2.677439e+06     0.114817
# 2  406935.23018  2013  3.405746e+06     0.119485
# 3  504165.97046  2014  4.299866e+06     0.117252

# %% [markdown]
# 从上面的结果可以看出，每年的利润和销售额一样，是在逐年增加的，说明企业经营还是比较妥善的，但是利润率总体平稳，稳定在11%-12%之间，总体利润率也还是不错的。

# %% [markdown]
# #### 4.1.4客单价分析

# %% [markdown]
# #### 客单价：是指商场（超市）每一个顾客平均购买商品的金额，客单价也即是平均交易金额。从某种程度上反映了企业的消费群体的许多特点以及企业的销售类目的盈利状态是否健康。
# #### 总消费次数：同一天内，同一个人发生的所有消费算作一次消费。
# #### 客单价=总消费金额 / 总消费次数

# %%
# 客单价分析
# 2011-2014年客单价
for i in range(2011,2015):
    data=df[df['year']==i]
    price=data[['Order_Date','Customer_ID','Sales']]

    # 计算总消费次数
    price_dr=price.drop_duplicates(
        subset=['Order_Date', 'Customer_ID'])

    # 总消费次数：有多少行
    total_num=price_dr.shape[0]
    print('{}年总消费次数='.format(i),total_num)

    unit_price = price['Sales'].sum()/total_num
    print('{}年客单价='.format(i), unit_price,'\n')
# Out:
# 2011年总消费次数= 4453
# 2011年客单价= 507.3997070604087
#
# 2012年总消费次数= 5392
# 2012年客单价= 496.55762136498515
#
# 2013年总消费次数= 6753
# 2013年客单价= 504.3308824788983
#
# 2014年总消费次数= 8696
# 2014年客单价= 494.4647965225392

# %% [markdown]
# 从上面结果来看，每年的消费次数呈不断上升趋势，但是客单价总体浮动范围不是很大 ，稳定在500左右。

# %% [markdown]
# #### 4.1.5市场布局分析

# %%
# 市场布局分析性
# 由于是全球超市  不同的地区市场不同  所以看一下不同地区间的销售情况
Market_Year_Sales = df.groupby(['Market', 'year']).agg({'Sales':'sum'}).reset_index().rename(columns={'Sales':'Sales_amounts'})
Market_Year_Sales.head()
# Out:
#    Market  year  Sales_amounts
# 0    APAC  2011   6.392453e+05
# 1    APAC  2012   7.627193e+05
# 2    APAC  2013   9.745809e+05
# 3    APAC  2014   1.209199e+06
# 4  Africa  2011   1.271873e+05

# %%
sns.barplot(x='Market', y='Sales_amounts', hue='year', data = Market_Year_Sales)
plt.title('2011-2014 market sales')
# Out:
# Text(0.5, 1.0, '2011-2014 market sales')

# %%
# 再看一下四年来各个地区销售额占总销售额的百分比。
Market_Sales = df.groupby(['Market']).agg({'Sales':'sum'})
Market_Sales["percent"] = Market_Sales["Sales"] / df["Sales"].sum()
Market_Sales.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0a073974_ae19_11ea_ba37_b42e998e8a14row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row1_col0 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row1_col1 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row3_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row3_col1 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row4_col0 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row4_col1 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row5_col0 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row5_col1 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row6_col0 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_0a073974_ae19_11ea_ba37_b42e998e8a14row6_col1 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }</style><table id="T_0a073974_ae19_11ea_ba37_b42e998e8a14" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sales</th>        <th class="col_heading level0 col1" >percent</th>    </tr>    <tr>        <th class="index_name level0" >Market</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a073974_ae19_11ea_ba37_b42e998e8a14level0_row0" class="row_heading level0 row0" >APAC</th>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row0_col0" class="data row0 col0" >3.58574e+06</td>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row0_col1" class="data row0 col1" >0.283626</td>
#             </tr>
#             <tr>
#                         <th id="T_0a073974_ae19_11ea_ba37_b42e998e8a14level0_row1" class="row_heading level0 row1" >Africa</th>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row1_col0" class="data row1 col0" >783773</td>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row1_col1" class="data row1 col1" >0.0619951</td>
#             </tr>
#             <tr>
#                         <th id="T_0a073974_ae19_11ea_ba37_b42e998e8a14level0_row2" class="row_heading level0 row2" >Canada</th>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row2_col0" class="data row2 col0" >66928.2</td>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row2_col1" class="data row2 col1" >0.0052939</td>
#             </tr>
#             <tr>
#                         <th id="T_0a073974_ae19_11ea_ba37_b42e998e8a14level0_row3" class="row_heading level0 row3" >EMEA</th>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row3_col0" class="data row3 col0" >806161</td>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row3_col1" class="data row3 col1" >0.063766</td>
#             </tr>
#             <tr>
#                         <th id="T_0a073974_ae19_11ea_ba37_b42e998e8a14level0_row4" class="row_heading level0 row4" >EU</th>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row4_col0" class="data row4 col0" >2.93809e+06</td>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row4_col1" class="data row4 col1" >0.232398</td>
#             </tr>
#             <tr>
#                         <th id="T_0a073974_ae19_11ea_ba37_b42e998e8a14level0_row5" class="row_heading level0 row5" >LATAM</th>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row5_col0" class="data row5 col0" >2.16461e+06</td>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row5_col1" class="data row5 col1" >0.171217</td>
#             </tr>
#             <tr>
#                         <th id="T_0a073974_ae19_11ea_ba37_b42e998e8a14level0_row6" class="row_heading level0 row6" >US</th>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row6_col0" class="data row6 col0" >2.2972e+06</td>
#                         <td id="T_0a073974_ae19_11ea_ba37_b42e998e8a14row6_col1" class="data row6 col1" >0.181705</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 从以上图表可以看出，每个地区每年销售额总体处于上升趋势，其中APAC(亚太地区)、EU(欧盟)、US(美国)、LATAM(拉丁美洲)的销售额超过了总销售额的85%，总体也与地区的经济发展相匹配。其中加拿大Canada的销售额微乎其微，可以结合公司整体战略布局进行取舍。

# %% [markdown]
# ### 4.2商品情况分析

# %%
#  商品情况分析

# 销量前十名商品
productId_count = df.groupby('Product_ID').count()['Customer_ID'].sort_values(ascending=False)
print(productId_count.head(10))
# Out:
# Product_ID
# OFF-AR-10003651    35
# OFF-AR-10003829    31
# OFF-BI-10002799    30
# OFF-BI-10003708    30
# FUR-CH-10003354    28
# OFF-BI-10002570    27
# OFF-BI-10004140    25
# OFF-BI-10004195    24
# OFF-BI-10001808    24
# OFF-BI-10004632    24
# Name: Customer_ID, dtype: int64

# %%
# 销售额前十名商品
productId_amount = df.groupby('Product_ID').sum()['Sales'].sort_values(ascending=False)
print(productId_amount.head(10))
# Out:
# Product_ID
# TEC-CO-10004722    61599.8240
# TEC-PH-10004664    30041.5482
# OFF-BI-10003527    27453.3840
# TEC-MA-10002412    22638.4800
# TEC-PH-10004823    22262.1000
# FUR-CH-10002024    21870.5760
# FUR-CH-10000027    21329.7300
# OFF-AP-10004512    21147.0840
# FUR-TA-10001889    20730.7557
# OFF-BI-10001359    19823.4790
# Name: Sales, dtype: float64

# %% [markdown]
# 从上面可以看出，销量最高的大部分是办公用品，而销售额最高的大部分是电子产品、家具这些单价较高的商品。

# %%
# 利润前十名商品
productId_Profit= df.groupby('Product_ID').sum()['Profit'].sort_values(ascending=False)
print(productId_Profit.head(10))
# Out:
# Product_ID
# TEC-CO-10004722    25199.9280
# OFF-AP-10004512    10345.5840
# TEC-PH-10004823     8121.4800
# OFF-BI-10003527     7753.0390
# TEC-CO-10001449     6983.8836
# FUR-CH-10002250     6123.2553
# TEC-PH-10004664     5455.9482
# OFF-AP-10002330     5452.4640
# TEC-PH-10000303     5356.8060
# FUR-CH-10002203     5003.1000
# Name: Profit, dtype: float64

# %% [markdown]
# 利润前10的商品有一半是电子产品，可以重点考虑提升这部分产品的销量，来增加整体的利润。

# %%
# 根据商品种类和子种类，重新重合成一个新的种类
df['Category_Sub_Category'] = df[['Category','Sub_Category']].apply(lambda x:str(x[0])+'_'+str(x[1]),axis=1)
# 按照新的种类进行分组，统计销售额和利润
df_Category_Sub_Category=df.groupby("Category_Sub_Category").agg({"Profit":"sum","Sales":"sum"}).reset_index()
# 按照销售额倒序排序
df_Category_Sub_Category.sort_values(by=["Sales"],ascending=False, inplace=True)
# 每个种类商品的销售额累计占比
df_Category_Sub_Category['cum_percent'] = df_Category_Sub_Category['Sales'].cumsum()/df_Category_Sub_Category['Sales'].sum()
df_Category_Sub_Category
# Out:
#          Category_Sub_Category        Profit         Sales  cum_percent
# 16           Technology_Phones  216717.00580  1.706824e+06     0.135007
# 14          Technology_Copiers  258567.54818  1.509436e+06     0.254401
# 1             Furniture_Chairs  140396.26750  1.501682e+06     0.373181
# 0          Furniture_Bookcases  161924.41950  1.466572e+06     0.489184
# 11     Office Supplies_Storage  108461.48980  1.127086e+06     0.578335
# 4   Office Supplies_Appliances  141680.58940  1.011064e+06     0.658308
# 15         Technology_Machines   58867.87300  7.790601e+05     0.719931
# 3             Furniture_Tables  -64083.38870  7.570419e+05     0.779811
# 13      Technology_Accessories  129626.30620  7.492370e+05     0.839075
# 6      Office Supplies_Binders   72449.84600  4.619115e+05     0.875611
# 2        Furniture_Furnishings   46967.42550  3.855783e+05     0.906110
# 5          Office Supplies_Art   57953.91090  3.720920e+05     0.935542
# 10       Office Supplies_Paper   59207.68270  2.442917e+05     0.954865
# 12    Office Supplies_Supplies   22583.26310  2.430742e+05     0.974091
# 7    Office Supplies_Envelopes   29601.11630  1.709043e+05     0.987610
# 8    Office Supplies_Fasteners   11525.42410  8.324232e+04     0.994194
# 9       Office Supplies_Labels   15010.51200  7.340403e+04     1.000000

# %% [markdown]
# 从图表中可以很清晰的看到不同种类商品的销售额贡献对比，有将近一半的商品的总销售占比达到84%，应该是自家优势主营产品，后续经营中应继续保持，可以结合整体战略发展适当加大投入，逐渐形成自己的品牌。
#
# 同时，也可以发现，末尾占比16%的产品中大部分是办公用品中的小物件。可以考虑与其他主营产品结合，连带销售来提升销量，或者考虑对这些商品进行优化。
#
# 但是值得关注的是，Tables(桌子)的利润是负，表明这个产品目前处于亏损状态，应该是促销让利太多。通过检查原数据，发现Tabels大部分都在打折，打折的销量高达76%。如果是在清库存，这个效果还是不错的，但如果不是，说明这个产品在市场推广上遇到了瓶颈，或者是遇到强竞争对手，需要结合实际业务进行分析，适当改善经营策略。

# %% [markdown]
# ### 4.3用户情况分析

# %% [markdown]
# #### 4.3.1不同类型用户占比

# %%
df["Segment"].value_counts().plot(kind='pie', autopct='%.2f%%', shadow=True, figsize=(14, 6))

# %% [markdown]
# 从上图可以看出，这四年来，普通消费者的客户占比最多，达到51.7%。

# %%
# 每一年不同类型的客户数量情况。
Segment_Year = df.groupby(["Segment", 'year']).agg({'Customer_ID':'count'}).reset_index()
sns.barplot(x='Segment', y='Customer_ID', hue='year', data = Segment_Year)
plt.title('2011-2014 Segment Customer')
# Out:
# Text(0.5, 1.0, '2011-2014 Segment Customer')

# %% [markdown]
# 从上面可以看出，每类客户每年均在保持增长趋势，客户结构还是非常不错的。

# %%
# 不同类型的客户每年贡献的销售额。
Segment_sales = df.groupby(["Segment", 'year']).agg({'Sales':'sum'}).reset_index()
sns.barplot(x='Segment', y='Sales', hue='year', data = Segment_sales)
plt.title('2011-2014 Segment Sales')
# Out:
# Text(0.5, 1.0, '2011-2014 Segment Sales')

# %% [markdown]
# 各个类型的客户每年贡献的销售额都在稳步提升，普通消费者贡献的销售额最多，这和客户占比也有一定关系。

# %% [markdown]
# #### 4.3.2客户下单行为分析

# %%
# 首先截取Customer_ID, Order_Date, Quantity, Sales, month为新的子集，
# 并对Order_Date进行排序，方便后续分析 ：
grouped_Customer = df[['Customer_ID','Order_Date', 
          'Quantity', 'Sales', 'month']].sort_values(['Order_Date']).groupby('Customer_ID')
grouped_Customer.head()
# Out:
#       Customer_ID Order_Date  Quantity    Sales      month
# 0        TB-11280 2011-01-01         2  408.300 2011-01-01
# 1        JH-15985 2011-01-01         3  120.366 2011-01-01
# 2          AT-735 2011-01-01         4   66.120 2011-01-01
# 3        EM-14140 2011-01-01         3   44.865 2011-01-01
# 4        JH-15985 2011-01-01         5  113.670 2011-01-01
# ...           ...        ...       ...      ...        ...
# 43838      AD-180 2014-12-26         4  275.712 2014-12-01
# 43902     DB-3555 2014-12-26         1   18.180 2014-12-01
# 43878      AD-180 2014-12-26         2  158.760 2014-12-01
# 43914      AD-180 2014-12-26         2    4.272 2014-12-01
# 50246     DJ-3420 2014-12-30         4  157.800 2014-12-01
#
# [7857 rows x 5 columns]

# %%
# 用户的第一次购买日期分布。
grouped_Customer.min().Order_Date.value_counts().plot()

# %%
# 用户的最后一次购买日期分布。
grouped_Customer.max().Order_Date.value_counts().plot()

# %% [markdown]
# 从上面可以看出， 在13年初以后新用户增长的趋势缓慢，商家可以通过广告等推广策略吸收更多的新用户；而通过观察最近一次购买日期，可以发现用户基本没有流失，也验证了每年销售额的增长趋势。
#
# 总体来说新客户数量是在逐年递减的，说明该企业老客户的维系不错，但新客获取率较低。如果能够在新客户获取上能够突破，会给企业带来很大的增长空间。

# %%
# 只购买过一次的客户数量 。
# 统计每个客户第一次和最后一次购买记录
Customer_life = grouped_Customer.Order_Date.agg(['min','max'])
# 查看只有一次购买记录的顾客数量，第一次和最后一次是同一条记录，则说明购买只有一次
(Customer_life['min'] == Customer_life['max']).value_counts()
# Out:
# False    1580
# True       10
# dtype: int64

# %% [markdown]
# 从结果来看，只购买一次的用户只有10个，大部分用户都会购买多次，说明回头率很高，也验证了上面关于该企业老客户的维系不错的结论。

# %% [markdown]
# #### 4.3.3  RFM模型分析

# %% [markdown]
# RFM的含义：
#
# R（Recency）：客户最近一次交易时间的间隔。R值越大，表示客户交易发生的日期越久，反之则表示客户交易发生的日期越近。
#
# F（Frequency）：客户在最近一段时间内交易的次数。F值越大，表示客户交易越频繁，反之则表示客户交易不够活跃。
#
# M（Monetary）：客户在最近一段时间内交易的金额。M值越大，表示客户价值越高，反之则表示客户价值越低。
#
# RFM分析就是根据客户活跃程度和交易金额的贡献，进行客户价值细分的一种方法。
# 首先构建RFM表。

# %%
rfm = df.pivot_table(index='Customer_ID',
                    values = ["Quantity","Sales","Order_Date"],
              aggfunc={"Quantity":"sum","Sales":"sum","Order_Date":"max"})

# 所有用户最大的交易日期为标准，求每笔交易的时间间隔即为R
rfm['R'] = (rfm.Order_Date.max() - rfm.Order_Date)/np.timedelta64(1,'D')
# 每个客户的总销量即为F，总销售额即为M
rfm.rename(columns={'Quantity':'F','Sales':'M'},inplace = True)
rfm.head()
# Out:
#             Order_Date    F            M      R
# Customer_ID
# AA-10315    2014-12-23  145  13747.41300    8.0
# AA-10375    2014-12-25  139   5884.19500    6.0
# AA-10480    2014-09-05  150  17695.58978  117.0
# AA-10645    2014-12-05  267  15343.89070   26.0
# AA-315      2014-12-29   20   2243.25600    2.0

# %%
# 对客户价值进行标注，将客户分为8个等级。

# 基于平均值做比较，超过均值为1，否则为0
rfm[['R','F','M']].apply(lambda x:x-x.mean())

def rfm_func(x):
    level =x.apply(lambda x:'1'if x>0 else '0')
    level =level.R +level.F +level.M
    d = {
        "111":"重要价值客户",
        "011":"重要保持客户",
        "101":"重要挽留客户",
        "001":"重要发展客户",
        "110":"一般价值客户",
        "010":"一般保持客户",
        "100":"一般挽留客户",
        "000":"一般发展客户"
    }
    result = d[level]
    return result

rfm['label']= rfm[['R','F','M']].apply(lambda x:x-x.mean()).apply(rfm_func,axis =1)
rfm.head()
# Out:
#             Order_Date    F            M      R   label
# Customer_ID
# AA-10315    2014-12-23  145  13747.41300    8.0  重要保持客户
# AA-10375    2014-12-25  139   5884.19500    6.0  一般保持客户
# AA-10480    2014-09-05  150  17695.58978  117.0  重要价值客户
# AA-10645    2014-12-05  267  15343.89070   26.0  重要保持客户
# AA-315      2014-12-29   20   2243.25600    2.0  一般发展客户

# %%
# 对重要价值客户和非重要价值客户进行可视化展示。
rfm.loc[rfm.label=='重要价值客户','color']='g'
rfm.loc[~(rfm.label=='重要价值客户'),'color']='r'
rfm.plot.scatter('F','R',c= rfm.color)

# %% [markdown]
# 通过RFM识别不同的客户群体，能够衡量客户价值和客户利润创收能力，可以指定个性化的沟通和营销服务，为更多的营销决策提供有力支持，为企业创造更大的利益。

# %% [markdown]
# #### 4.3.4新用户、活跃用户、不活跃用户和回归用户分析

# %%
# 设置Customer_ID为索引，month为列名，统计每个月的购买次数。
pivoted_counts = df.pivot_table(index= 'Customer_ID',
                               columns= 'month',
                               values= 'Order_Date',
                               aggfunc= 'count').fillna(0)
# 大于一次的全部设为1
df_purchase = pivoted_counts.applymap(lambda x:1 if x>0 else 0)
df_purchase.head()
# Out:
# month        2011-01-01  2011-02-01  2011-03-01  2011-04-01  2011-05-01  \
# Customer_ID
# AA-10315              0           0           1           1           0
# AA-10375              0           0           0           1           0
# AA-10480              1           0           1           1           0
# AA-10645              1           0           0           1           0
# AA-315                0           0           0           0           0
#
# month        2011-06-01  2011-07-01  2011-08-01  2011-09-01  2011-10-01  ...  \
# Customer_ID                                                              ...
# AA-10315              0           0           0           1           0  ...
# AA-10375              0           1           0           0           1  ...
# AA-10480              1           0           1           0           0  ...
# AA-10645              1           1           0           0           0  ...
# AA-315                0           0           1           0           0  ...
#
# month        2014-03-01  2014-04-01  2014-05-01  2014-06-01  2014-07-01  \
# Customer_ID
# AA-10315              0           1           0           1           1
# AA-10375              0           0           0           0           0
# AA-10480              1           1           1           0           0
# AA-10645              1           1           0           1           0
# AA-315                0           0           1           0           1
#
# month        2014-08-01  2014-09-01  2014-10-01  2014-11-01  2014-12-01
# Customer_ID
# AA-10315              1           0           0           0           1
# AA-10375              1           0           1           1           1
# AA-10480              1           1           0           0           0
# AA-10645              0           0           1           1           1
# AA-315                0           0           0           0           1
#
# [5 rows x 48 columns]

# %%
# 定义状态函数并进行状态标记。
def active_status(data):
    status = []
    for i in range(48):
        if data[i] == 0:
            if len(status)>0:
                if status[i-1] == "unreg":
                 # 未注册客户
                    status.append("unreg")
                else:
                 # 不活跃用户
                    status.append("unactive")
            else:
                status.append("unreg")
            
        # 若本月消费了
        else:
            if len(status) == 0:
             # 新用户
                status.append("new")
            else:
                if status[i-1] == "unactive":
                 # 回归用户
                    status.append("return")
                elif status[i-1] == "unreg":
                    status.append("new")
                else:
                    status.append("active")
    return pd.Series(status)  

purchase_stats = df_purchase.apply(active_status,axis =1)
purchase_stats.head()
# Out:
#                 0         1         2       3         4         5         6   \
# Customer_ID
# AA-10315     unreg     unreg       new  active  unactive  unactive  unactive
# AA-10375     unreg     unreg     unreg     new  unactive  unactive    return
# AA-10480       new  unactive    return  active  unactive    return  unactive
# AA-10645       new  unactive  unactive  return  unactive    return    active
# AA-315       unreg     unreg     unreg   unreg     unreg     unreg     unreg
#
#                    7         8         9   ...        38        39        40  \
# Customer_ID                                ...
# AA-10315     unactive    return  unactive  ...  unactive    return  unactive
# AA-10375     unactive  unactive    return  ...  unactive  unactive  unactive
# AA-10480       return  unactive  unactive  ...    return    active    active
# AA-10645     unactive  unactive  unactive  ...    return    active  unactive
# AA-315            new  unactive  unactive  ...  unactive  unactive    return
#
#                    41        42        43        44        45        46  \
# Customer_ID
# AA-10315       return    active    active  unactive  unactive  unactive
# AA-10375     unactive  unactive    return  unactive    return    active
# AA-10480     unactive  unactive    return    active  unactive  unactive
# AA-10645       return  unactive  unactive  unactive    return    active
# AA-315       unactive    return  unactive  unactive  unactive  unactive
#
#                    47
# Customer_ID
# AA-10315       return
# AA-10375       active
# AA-10480     unactive
# AA-10645       active
# AA-315         return
#
# [5 rows x 48 columns]

# %%
# 用NaN替代 "unreg"，并统计每月各状态客户数量。
purchase_stats_ct = purchase_stats.replace('unreg',np.NaN).apply(lambda x:pd.value_counts(x))
# 用0填充NaN
purchase_stats_ct.fillna(0).T.plot.area()

# %% [markdown]
# 从以上结果可以发现活跃客户、新客户和回归客户，每年呈一定的规律起伏，这可能和年终年末大促有关，需要更多数据进行佐证；同时可以发现新客数量每年均在减少，说明该商家新客获取率较低，如果能在新客户获取上取得突破，会给商家带来很大的增长空间。

# %% [markdown]
# #### 4.3.5复购率和回购率分析

# %%
# 复购率计算指标：用户在该月购买过一次以上算复购。
purchase_r = pivoted_counts.applymap(lambda x :1 if x>1 else np.NaN if x==0 else 0)
(purchase_r.sum()/purchase_r.count()).plot(figsize=(10,4))

# %%
# 回购率计算指标：在该月购买过，且在下月也购买时计入回购。
def purchase_back(data):
    status=[]
    for i in range(47):
        if data[i] ==1:
            if data[i+1] == 1:
                status.append(1)
            if data[i+1] == 0:
                status.append(0)
        else:
            status.append(np.NaN)
    status.append(np.NaN)
    return status

purchase_b = df_purchase.apply(purchase_back,axis =1,result_type='expand')
(purchase_b.sum()/purchase_b.count()).plot(figsize=(10,4))

# %% [markdown]
# 从上可以发现复购率基本大于0.525，且呈总体上升趋势，说明客户忠诚度高，回购率在年中年末呈峰形态，可能与商家折扣活动或节日有关。
